# %% [markdown]
# # LangChain Fundamentals
#
# - LangChain
# - Components
# - Agents

# %%
- open source framework
- development, deployment, and productionizing LLMs

- third party integrations
- chains, agents, retrieval strategies
- LangGraph - creating stateful multi-actor applications
- LangServe - for deploying LangChain as REST APIs

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Architecture
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Components

# %%
- prompts
- output parser - classes that help structure language model responses
- retrievers - accept a string of query and return a list of documents
- document loader
- indexes - in langchain index is a data strucutre
- vector stores - to do the vector search on vector store of embedded data (unstructured data)
- agents - decision making components that decides the plan of action or process
- chains - sequence of calls, 
- tool - specific funtion to gather information from LLM for task completion (google search, databases, python repl, and other chains)

# %% [markdown]
# ## application of langchain
#
# ![image.png](attachment:image.png)
